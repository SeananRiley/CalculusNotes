# %% [markdown]
# # Calculus Notes - Lesson 28

# %% [markdown]
# ## Slope Fields
# A slope field is a way of visualizing a differential equation. You can graph the tangent slope at a series of points on a graph.
#
# For example this is the plot of $y' = x + y$
#
# ![Fig28-1.PNG](attachment:Fig28-1.PNG)

# %% [markdown]
# ## Matching functions to slope fields
#
# Looking at a slope field can help us guess what function might be a solution to a differential equations.
#
# For exampe: option e is the most likely fit to the following slope field:

# %% [markdown]
# ![Fig28-2.PNG](attachment:Fig28-2.PNG)
